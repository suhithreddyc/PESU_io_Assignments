# %% [markdown]
# <a href="https://colab.research.google.com/github/suhithreddyc/PESU_io_Assignments/blob/main/ASSIGNMENT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv('/content/SwedishMotorInsurance.csv')
y = dataset.iloc[:, 5].values
X = dataset.iloc[:, 6:7].values

# %%
X
# Out:
# array([[392491],
#        [ 46221],
#        [ 15694],
#        ...,
#        [   966],
#        [     0],
#        [112252]])

# %%
y
# Out:
# array([1, 1, 1, ..., 7, 7, 7])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
from pandas.core.tools.datetimes import YearMonthDayDict
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_train,y_train)
lin_reg.predict([[20]])
# Out:
# array([1.54022439])

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('zone')
plt.ylabel('payment')
plt.show()
